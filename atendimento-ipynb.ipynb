# %%
import simpy
import random

import pandas as pd

class Atendimento:
    def __init__(self, env, num_atendentes, taxa_chegada, tempo_atendimento):
        self.env = env
        self.num_atendentes = num_atendentes
        self.taxa_chegada = taxa_chegada
        self.tempo_atendimento = tempo_atendimento
        self.fila = []
        self.atendentes = [None] * self.num_atendentes
        
        self.num_clientes_total = 0
        self.num_clientes_atendidos = 0
        self.tempo_espera_total = 0
        self.tempo_atendimento_total = 0
        
        self.proxima_chegada = self.gera_chegada()
        self.env.process(self.chegada_cliente())
        
    def gera_chegada(self):
        return random.expovariate(self.taxa_chegada)
    
    def gera_tempo_atendimento(self):
        return random.expovariate(1.0 / self.tempo_atendimento)
    
    def chegada_cliente(self):
        while True:
            # Aguarda a chegada do próximo cliente
            yield self.env.timeout(self.proxima_chegada)
            
            # Gera um novo cliente e adiciona à fila
            self.num_clientes_total += 1
            nome = f"Cliente {self.num_clientes_total}"
            cliente = {'nome': nome, 'hora_chegada': self.env.now, 'hora_atendimento': None, 'tempo_espera': 0}
            self.fila.append(cliente)
            print(f"{nome} chegou ao sistema no tempo {self.env.now:.2f} minutos e entrou na fila.")
            print("Fila de espera:", [cliente['nome'] for cliente in self.fila]) # adiciona essa linha para imprimir a fila
            
            # Inicia o atendimento se houver atendentes disponíveis
            if None in self.atendentes:
                self.env.process(self.execucao_atendimento())

            # Agenda a próxima chegada
            self.proxima_chegada = self.gera_chegada()
            
    def execucao_atendimento(self):
        # Seleciona um atendente disponível
        atendente = self.atendentes.index(None)
        
        # Seleciona o próximo cliente da fila
        cliente = self.fila.pop(0)
        nome = cliente['nome']
        
        # Inicia o atendimento
        self.atendentes[atendente] = nome
        cliente['hora_atendimento'] = self.env.now
        tempo_atendimento = self.gera_tempo_atendimento()
        yield self.env.timeout(tempo_atendimento)
        self.atendentes[atendente] = None

        # Atualiza as estatísticas do sistema
        cliente['tempo_espera'] = cliente['hora_atendimento'] - cliente['hora_chegada']
        self.num_clientes_atendidos += 1
        self.tempo_espera_total += cliente['tempo_espera']
        self.tempo_atendimento_total += tempo_atendimento
        print(f"{nome} foi atendido pelo atendente {atendente + 1} no tempo {self.env.now:.2f} minutos.")


    # Verifica se o cliente desistiu da fila
    if random.uniform(0, 1) < prob_desistencia and any(cliente['nome'] == nome for cliente in fila):
        fila = [cliente for cliente in fila if cliente['nome'] != nome]
        print(f"{nome} desistiu da fila no tempo {env.now:.2f} minutos.")

# %%
env = simpy.Environment()
atendimento = Atendimento(env, num_atendentes=2, taxa_chegada=10/60, tempo_atendimento=5)
env.run(until=8*60)
# Out:
# Cliente 1 chegou ao sistema no tempo 9.17 minutos e entrou na fila.
# Fila de espera: ['Cliente 1']
# Cliente 2 chegou ao sistema no tempo 17.34 minutos e entrou na fila.
# Fila de espera: ['Cliente 2']
# Cliente 2 foi atendido pelo atendente 2 no tempo 17.78 minutos.
# Cliente 1 foi atendido pelo atendente 1 no tempo 19.01 minutos.
# Cliente 3 chegou ao sistema no tempo 22.47 minutos e entrou na fila.
# Fila de espera: ['Cliente 3']
# Cliente 3 foi atendido pelo atendente 1 no tempo 24.01 minutos.
# Cliente 4 chegou ao sistema no tempo 27.59 minutos e entrou na fila.
# Fila de espera: ['Cliente 4']
# Cliente 4 foi atendido pelo atendente 1 no tempo 29.64 minutos.
# Cliente 5 chegou ao sistema no tempo 31.29 minutos e entrou na fila.
# Fila de espera: ['Cliente 5']
# Cliente 6 chegou ao sistema no tempo 34.00 minutos e entrou na fila.
# Fila de espera: ['Cliente 6']
# Cliente 7 chegou ao sistema no tempo 34.21 minutos e entrou na fila.
# Fila de espera: ['Cliente 7']
# Cliente 6 foi atendido pelo atendente 2 no tempo 35.58 minutos.
# Cliente 8 chegou ao sistema no tempo 35.70 minutos e entrou na fila.
# Fila de espera: ['Cliente 7', 'Cliente 8']
# Cliente 7 foi atendido pelo atendente 2 no tempo 37.21 minutos.
# Cliente 9 chegou ao sistema no tempo 48.59 minutos e entrou na fila.
# Fila de espera: ['Cliente 8', 'Cliente 9']
# Cliente 10 chegou ao sistema no tempo 52.16 minutos e entrou na fila.
# Fila de espera: ['Cliente 9', 'Cliente 10']
# Cliente 5 foi atendido pelo atendente 1 no tempo 52.63 minutos.
# Cliente 11 chegou ao sistema no tempo 53.81 minutos e entrou na fila.
# Fila de espera: ['Cliente 9', 'Cliente 10', 'Cliente 11']
# Cliente 8 foi atendido pelo atendente 2 no tempo 54.20 minutos.
# Cliente 12 chegou ao sistema no tempo 59.76 minutos e entrou na fila.
# Fila de espera: ['Cliente 10', 'Cliente 11', 'Cliente 12']
# Cliente 10 foi atendido pelo atendente 2 no tempo 60.82 minutos.
# Cliente 9 foi atendido pelo atendente 1 no tempo 62.51 minutos.
# Cliente 13 chegou ao sistema no tempo 79.37 minutos e entrou na fila.
# Fila de espera: ['Cliente 11', 'Cliente 12', 'Cliente 13']
# Cliente 14 chegou ao sistema no tempo 81.33 minutos e entrou na fila.
# Fila de espera: ['Cliente 12', 'Cliente 13', 'Cliente 14']
# Cliente 15 chegou ao sistema no tempo 81.58 minutos e entrou na fila.
# Fila de espera: ['Cliente 13', 'Cliente 14', 'Cliente 15']
# Cliente 12 foi atendido pelo atendente 2 no tempo 83.57 minutos.
# Cliente 11 foi atendido pelo atendente 1 no tempo 86.68 minutos.
# Cliente 16 chegou ao sistema no tempo 88.94 minutos e entrou na fila.
# Fila de espera: ['Cliente 13', 'Cliente 14', 'Cliente 15', 'Cliente 16']
# Cliente 13 foi atendido pelo atendente 1 no tempo 101.09 minutos.
# Cliente 17 chegou ao sistema no tempo 105.55 minutos e entrou na fila.
# Fila de espera: ['Cliente 14', 'Cliente 15', 'Cliente 16', 'Cliente 17']
# Cliente 14 foi atendido pelo atendente 1 no tempo 106.85 minutos.
# Cliente 18 chegou ao sistema no tempo 111.91 minutos e entrou na fila.
# Fila de espera: ['Cliente 15', 'Cliente 16', 'Cliente 17', 'Cliente 18']
# Cliente 15 foi atendido pelo atendente 1 no tempo 114.12 minutos.
# Cliente 19 chegou ao sistema no tempo 115.25 minutos e entrou na fila.
# Fila de espera: ['Cliente 16', 'Cliente 17', 'Cliente 18', 'Cliente 19']
# Cliente 20 chegou ao sistema no tempo 122.74 minutos e entrou na fila.
# Fila de espera: ['Cliente 17', 'Cliente 18', 'Cliente 19', 'Cliente 20']
# Cliente 16 foi atendido pelo atendente 1 no tempo 126.30 minutos.
# Cliente 21 chegou ao sistema no tempo 127.92 minutos e entrou na fila.
# Fila de espera: ['Cliente 18', 'Cliente 19', 'Cliente 20', 'Cliente 21']
# Cliente 18 foi atendido pelo atendente 1 no tempo 128.96 minutos.
# Cliente 22 chegou ao sistema no tempo 129.34 minutos e entrou na fila.
# Fila de espera: ['Cliente 19', 'Cliente 20', 'Cliente 21', 'Cliente 22']
# Cliente 23 chegou ao sistema no tempo 129.61 minutos e entrou na fila.
# Fila de espera: ['Cliente 20', 'Cliente 21', 'Cliente 22', 'Cliente 23']
# Cliente 17 foi atendido pelo atendente 2 no tempo 130.34 minutos.
# Cliente 19 foi atendido pelo atendente 1 no tempo 137.12 minutos.
# Cliente 24 chegou ao sistema no tempo 165.86 minutos e entrou na fila.
# Fila de espera: ['Cliente 20', 'Cliente 21', 'Cliente 22', 'Cliente 23', 'Cliente 24']
# Cliente 25 chegou ao sistema no tempo 167.87 minutos e entrou na fila.
# Fila de espera: ['Cliente 21', 'Cliente 22', 'Cliente 23', 'Cliente 24', 'Cliente 25']
# Cliente 21 foi atendido pelo atendente 2 no tempo 169.74 minutos.
# Cliente 26 chegou ao sistema no tempo 169.88 minutos e entrou na fila.
# Fila de espera: ['Cliente 22', 'Cliente 23', 'Cliente 24', 'Cliente 25', 'Cliente 26']
# Cliente 27 chegou ao sistema no tempo 170.18 minutos e entrou na fila.
# Fila de espera: ['Cliente 23', 'Cliente 24', 'Cliente 25', 'Cliente 26', 'Cliente 27']
# Cliente 22 foi atendido pelo atendente 2 no tempo 170.33 minutos.
# Cliente 28 chegou ao sistema no tempo 172.29 minutos e entrou na fila.
# Fila de espera: ['Cliente 23', 'Cliente 24', 'Cliente 25', 'Cliente 26', 'Cliente 27', 'Cliente 28']
# Cliente 20 foi atendido pelo atendente 1 no tempo 173.89 minutos.
# Cliente 29 chegou ao sistema no tempo 174.39 minutos e entrou na fila.
# Fila de espera: ['Cliente 24', 'Cliente 25', 'Cliente 26', 'Cliente 27', 'Cliente 28', 'Cliente 29']
# Cliente 24 foi atendido pelo atendente 1 no tempo 174.87 minutos.
# Cliente 30 chegou ao sistema no tempo 183.92 minutos e entrou na fila.
# Fila de espera: ['Cliente 25', 'Cliente 26', 'Cliente 27', 'Cliente 28', 'Cliente 29', 'Cliente 30']
# Cliente 23 foi atendido pelo atendente 2 no tempo 184.24 minutos.
# Cliente 25 foi atendido pelo atendente 1 no tempo 184.78 minutos.
# Cliente 31 chegou ao sistema no tempo 192.74 minutos e entrou na fila.
# Fila de espera: ['Cliente 26', 'Cliente 27', 'Cliente 28', 'Cliente 29', 'Cliente 30', 'Cliente 31']
# Cliente 26 foi atendido pelo atendente 1 no tempo 198.38 minutos.
# Cliente 32 chegou ao sistema no tempo 201.25 minutos e entrou na fila.
# Fila de espera: ['Cliente 27', 'Cliente 28', 'Cliente 29', 'Cliente 30', 'Cliente 31', 'Cliente 32']
# Cliente 27 foi atendido pelo atendente 1 no tempo 203.04 minutos.
# Cliente 33 chegou ao sistema no tempo 205.88 minutos e entrou na fila.
# Fila de espera: ['Cliente 28', 'Cliente 29', 'Cliente 30', 'Cliente 31', 'Cliente 32', 'Cliente 33']
# Cliente 34 chegou ao sistema no tempo 207.91 minutos e entrou na fila.
# Fila de espera: ['Cliente 29', 'Cliente 30', 'Cliente 31', 'Cliente 32', 'Cliente 33', 'Cliente 34']
# Cliente 28 foi atendido pelo atendente 1 no tempo 209.97 minutos.
# Cliente 35 chegou ao sistema no tempo 214.58 minutos e entrou na fila.
# Fila de espera: ['Cliente 30', 'Cliente 31', 'Cliente 32', 'Cliente 33', 'Cliente 34', 'Cliente 35']
# Cliente 36 chegou ao sistema no tempo 217.51 minutos e entrou na fila.
# Fila de espera: ['Cliente 31', 'Cliente 32', 'Cliente 33', 'Cliente 34', 'Cliente 35', 'Cliente 36']
# Cliente 37 chegou ao sistema no tempo 224.73 minutos e entrou na fila.
# Fila de espera: ['Cliente 31', 'Cliente 32', 'Cliente 33', 'Cliente 34', 'Cliente 35', 'Cliente 36', 'Cliente 37']
# Cliente 38 chegou ao sistema no tempo 226.49 minutos e entrou na fila.
# Fila de espera: ['Cliente 31', 'Cliente 32', 'Cliente 33', 'Cliente 34', 'Cliente 35', 'Cliente 36', 'Cliente 37', 'Cliente 38']
# Cliente 30 foi atendido pelo atendente 1 no tempo 229.76 minutos.
# Cliente 29 foi atendido pelo atendente 2 no tempo 231.38 minutos.
# Cliente 39 chegou ao sistema no tempo 234.31 minutos e entrou na fila.
# Fila de espera: ['Cliente 31', 'Cliente 32', 'Cliente 33', 'Cliente 34', 'Cliente 35', 'Cliente 36', 'Cliente 37', 'Cliente 38', 'Cliente 39']
# Cliente 31 foi atendido pelo atendente 1 no tempo 238.11 minutos.
# Cliente 40 chegou ao sistema no tempo 238.92 minutos e entrou na fila.
# Fila de espera: ['Cliente 32', 'Cliente 33', 'Cliente 34', 'Cliente 35', 'Cliente 36', 'Cliente 37', 'Cliente 38', 'Cliente 39', 'Cliente 40']
# Cliente 32 foi atendido pelo atendente 1 no tempo 240.49 minutos.
# Cliente 41 chegou ao sistema no tempo 241.80 minutos e entrou na fila.
# Fila de espera: ['Cliente 33', 'Cliente 34', 'Cliente 35', 'Cliente 36', 'Cliente 37', 'Cliente 38', 'Cliente 39', 'Cliente 40', 'Cliente 41']
# Cliente 42 chegou ao sistema no tempo 247.24 minutos e entrou na fila.
# Fila de espera: ['Cliente 34', 'Cliente 35', 'Cliente 36', 'Cliente 37', 'Cliente 38', 'Cliente 39', 'Cliente 40', 'Cliente 41', 'Cliente 42']
# Cliente 33 foi atendido pelo atendente 1 no tempo 249.48 minutos.
# Cliente 34 foi atendido pelo atendente 2 no tempo 249.59 minutos.
# Cliente 43 chegou ao sistema no tempo 260.48 minutos e entrou na fila.
# Fila de espera: ['Cliente 35', 'Cliente 36', 'Cliente 37', 'Cliente 38', 'Cliente 39', 'Cliente 40', 'Cliente 41', 'Cliente 42', 'Cliente 43']
# Cliente 35 foi atendido pelo atendente 1 no tempo 262.45 minutos.
# Cliente 44 chegou ao sistema no tempo 270.22 minutos e entrou na fila.
# Fila de espera: ['Cliente 36', 'Cliente 37', 'Cliente 38', 'Cliente 39', 'Cliente 40', 'Cliente 41', 'Cliente 42', 'Cliente 43', 'Cliente 44']
# Cliente 45 chegou ao sistema no tempo 274.77 minutos e entrou na fila.
# Fila de espera: ['Cliente 37', 'Cliente 38', 'Cliente 39', 'Cliente 40', 'Cliente 41', 'Cliente 42', 'Cliente 43', 'Cliente 44', 'Cliente 45']
# Cliente 36 foi atendido pelo atendente 1 no tempo 275.72 minutos.
# Cliente 37 foi atendido pelo atendente 2 no tempo 276.63 minutos.
# Cliente 46 chegou ao sistema no tempo 286.22 minutos e entrou na fila.
# Fila de espera: ['Cliente 38', 'Cliente 39', 'Cliente 40', 'Cliente 41', 'Cliente 42', 'Cliente 43', 'Cliente 44', 'Cliente 45', 'Cliente 46']
# Cliente 47 chegou ao sistema no tempo 289.29 minutos e entrou na fila.
# Fila de espera: ['Cliente 39', 'Cliente 40', 'Cliente 41', 'Cliente 42', 'Cliente 43', 'Cliente 44', 'Cliente 45', 'Cliente 46', 'Cliente 47']
# Cliente 38 foi atendido pelo atendente 1 no tempo 289.37 minutos.
# Cliente 39 foi atendido pelo atendente 2 no tempo 296.83 minutos.
# Cliente 48 chegou ao sistema no tempo 297.28 minutos e entrou na fila.
# Fila de espera: ['Cliente 40', 'Cliente 41', 'Cliente 42', 'Cliente 43', 'Cliente 44', 'Cliente 45', 'Cliente 46', 'Cliente 47', 'Cliente 48']
# Cliente 49 chegou ao sistema no tempo 303.06 minutos e entrou na fila.
# Fila de espera: ['Cliente 41', 'Cliente 42', 'Cliente 43', 'Cliente 44', 'Cliente 45', 'Cliente 46', 'Cliente 47', 'Cliente 48', 'Cliente 49']
# Cliente 40 foi atendido pelo atendente 1 no tempo 303.98 minutos.
# Cliente 50 chegou ao sistema no tempo 306.73 minutos e entrou na fila.
# Fila de espera: ['Cliente 42', 'Cliente 43', 'Cliente 44', 'Cliente 45', 'Cliente 46', 'Cliente 47', 'Cliente 48', 'Cliente 49', 'Cliente 50']
# Cliente 51 chegou ao sistema no tempo 306.88 minutos e entrou na fila.
# Fila de espera: ['Cliente 43', 'Cliente 44', 'Cliente 45', 'Cliente 46', 'Cliente 47', 'Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51']
# Cliente 52 chegou ao sistema no tempo 309.81 minutos e entrou na fila.
# Fila de espera: ['Cliente 43', 'Cliente 44', 'Cliente 45', 'Cliente 46', 'Cliente 47', 'Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52']
# Cliente 42 foi atendido pelo atendente 1 no tempo 309.88 minutos.
# Cliente 53 chegou ao sistema no tempo 312.32 minutos e entrou na fila.
# Fila de espera: ['Cliente 43', 'Cliente 44', 'Cliente 45', 'Cliente 46', 'Cliente 47', 'Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53']
# Cliente 41 foi atendido pelo atendente 2 no tempo 316.76 minutos.
# Cliente 43 foi atendido pelo atendente 1 no tempo 318.14 minutos.
# Cliente 54 chegou ao sistema no tempo 336.15 minutos e entrou na fila.
# Fila de espera: ['Cliente 44', 'Cliente 45', 'Cliente 46', 'Cliente 47', 'Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54']
# Cliente 55 chegou ao sistema no tempo 338.95 minutos e entrou na fila.
# Fila de espera: ['Cliente 45', 'Cliente 46', 'Cliente 47', 'Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55']
# Cliente 45 foi atendido pelo atendente 2 no tempo 343.57 minutos.
# Cliente 56 chegou ao sistema no tempo 344.30 minutos e entrou na fila.
# Fila de espera: ['Cliente 46', 'Cliente 47', 'Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56']
# Cliente 57 chegou ao sistema no tempo 345.28 minutos e entrou na fila.
# Fila de espera: ['Cliente 47', 'Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57']
# Cliente 58 chegou ao sistema no tempo 350.12 minutos e entrou na fila.
# Fila de espera: ['Cliente 47', 'Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58']
# Cliente 46 foi atendido pelo atendente 2 no tempo 353.57 minutos.
# Cliente 59 chegou ao sistema no tempo 356.74 minutos e entrou na fila.
# Fila de espera: ['Cliente 47', 'Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59']
# Cliente 60 chegou ao sistema no tempo 359.70 minutos e entrou na fila.
# Fila de espera: ['Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60']
# Cliente 61 chegou ao sistema no tempo 360.45 minutos e entrou na fila.
# Fila de espera: ['Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61']
# Cliente 62 chegou ao sistema no tempo 362.26 minutos e entrou na fila.
# Fila de espera: ['Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62']
# Cliente 47 foi atendido pelo atendente 2 no tempo 364.98 minutos.
# Cliente 44 foi atendido pelo atendente 1 no tempo 367.16 minutos.
# Cliente 63 chegou ao sistema no tempo 399.48 minutos e entrou na fila.
# Fila de espera: ['Cliente 48', 'Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63']
# Cliente 64 chegou ao sistema no tempo 401.09 minutos e entrou na fila.
# Fila de espera: ['Cliente 49', 'Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64']
# Cliente 65 chegou ao sistema no tempo 403.05 minutos e entrou na fila.
# Fila de espera: ['Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65']
# Cliente 49 foi atendido pelo atendente 2 no tempo 406.29 minutos.
# Cliente 66 chegou ao sistema no tempo 408.51 minutos e entrou na fila.
# Fila de espera: ['Cliente 50', 'Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66']
# Cliente 67 chegou ao sistema no tempo 408.99 minutos e entrou na fila.
# Fila de espera: ['Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66', 'Cliente 67']
# Cliente 48 foi atendido pelo atendente 1 no tempo 409.89 minutos.
# Cliente 68 chegou ao sistema no tempo 410.63 minutos e entrou na fila.
# Fila de espera: ['Cliente 51', 'Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66', 'Cliente 67', 'Cliente 68']
# Cliente 51 foi atendido pelo atendente 1 no tempo 410.85 minutos.
# Cliente 69 chegou ao sistema no tempo 413.68 minutos e entrou na fila.
# Fila de espera: ['Cliente 52', 'Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66', 'Cliente 67', 'Cliente 68', 'Cliente 69']
# Cliente 50 foi atendido pelo atendente 2 no tempo 415.60 minutos.
# Cliente 70 chegou ao sistema no tempo 419.38 minutos e entrou na fila.
# Fila de espera: ['Cliente 53', 'Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66', 'Cliente 67', 'Cliente 68', 'Cliente 69', 'Cliente 70']
# Cliente 53 foi atendido pelo atendente 2 no tempo 419.76 minutos.
# Cliente 52 foi atendido pelo atendente 1 no tempo 421.96 minutos.
# Cliente 71 chegou ao sistema no tempo 426.48 minutos e entrou na fila.
# Fila de espera: ['Cliente 54', 'Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66', 'Cliente 67', 'Cliente 68', 'Cliente 69', 'Cliente 70', 'Cliente 71']
# Cliente 54 foi atendido pelo atendente 1 no tempo 433.96 minutos.
# Cliente 72 chegou ao sistema no tempo 435.56 minutos e entrou na fila.
# Fila de espera: ['Cliente 55', 'Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66', 'Cliente 67', 'Cliente 68', 'Cliente 69', 'Cliente 70', 'Cliente 71', 'Cliente 72']
# Cliente 55 foi atendido pelo atendente 1 no tempo 437.04 minutos.
# Cliente 73 chegou ao sistema no tempo 437.14 minutos e entrou na fila.
# Fila de espera: ['Cliente 56', 'Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66', 'Cliente 67', 'Cliente 68', 'Cliente 69', 'Cliente 70', 'Cliente 71', 'Cliente 72', 'Cliente 73']
# Cliente 74 chegou ao sistema no tempo 440.75 minutos e entrou na fila.
# Fila de espera: ['Cliente 57', 'Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66', 'Cliente 67', 'Cliente 68', 'Cliente 69', 'Cliente 70', 'Cliente 71', 'Cliente 72', 'Cliente 73', 'Cliente 74']
# Cliente 56 foi atendido pelo atendente 1 no tempo 442.78 minutos.
# Cliente 75 chegou ao sistema no tempo 447.18 minutos e entrou na fila.
# Fila de espera: ['Cliente 58', 'Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66', 'Cliente 67', 'Cliente 68', 'Cliente 69', 'Cliente 70', 'Cliente 71', 'Cliente 72', 'Cliente 73', 'Cliente 74', 'Cliente 75']
# Cliente 58 foi atendido pelo atendente 1 no tempo 448.47 minutos.
# Cliente 57 foi atendido pelo atendente 2 no tempo 452.07 minutos.
# Cliente 76 chegou ao sistema no tempo 474.19 minutos e entrou na fila.
# Fila de espera: ['Cliente 59', 'Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66', 'Cliente 67', 'Cliente 68', 'Cliente 69', 'Cliente 70', 'Cliente 71', 'Cliente 72', 'Cliente 73', 'Cliente 74', 'Cliente 75', 'Cliente 76']
# Cliente 59 foi atendido pelo atendente 1 no tempo 474.83 minutos.
# Cliente 77 chegou ao sistema no tempo 476.11 minutos e entrou na fila.
# Fila de espera: ['Cliente 60', 'Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66', 'Cliente 67', 'Cliente 68', 'Cliente 69', 'Cliente 70', 'Cliente 71', 'Cliente 72', 'Cliente 73', 'Cliente 74', 'Cliente 75', 'Cliente 76', 'Cliente 77']
# Cliente 60 foi atendido pelo atendente 1 no tempo 476.17 minutos.
# Cliente 78 chegou ao sistema no tempo 479.55 minutos e entrou na fila.
# Fila de espera: ['Cliente 61', 'Cliente 62', 'Cliente 63', 'Cliente 64', 'Cliente 65', 'Cliente 66', 'Cliente 67', 'Cliente 68', 'Cliente 69', 'Cliente 70', 'Cliente 71', 'Cliente 72', 'Cliente 73', 'Cliente 74', 'Cliente 75', 'Cliente 76', 'Cliente 77', 'Cliente 78']
